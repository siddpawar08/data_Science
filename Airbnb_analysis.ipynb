# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Airbnb_Open_Data.csv")
# Out:
# <ipython-input-23-93d0b11f46c9>:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/Airbnb_Open_Data.csv")

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
# deleting some columns

col_to_drop = ['host id','country' ,'country code', 'lat' , 'long']

df.drop(col_to_drop , axis = 1,inplace = True)

# %%
df.head(5)
# Out:
#         id                                              NAME  \
# 0  1001254                Clean & quiet apt home by the park
# 1  1002102                             Skylit Midtown Castle
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3  1002755                                               NaN
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#   instant_bookable cancellation_policy        room type  Construction year  \
# 0            False              strict     Private room             2020.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host_identity_verified          102310 non-null  object
#  3   host name                       102193 non-null  object
#  4   neighbourhood group             102570 non-null  object
#  5   neighbourhood                   102583 non-null  object
#  6   instant_bookable                102494 non-null  object
#  7   cancellation_policy             102523 non-null  object
#  8   room type                       102599 non-null  object
#  9   Construction year               102385 non-null  float64
#  10  price                           102352 non-null  object
#  11  service fee                     102326 non-null  object
# ...

# %%
df.drop('license',axis = 1 , inplace=True)

# %%
df.drop('house_rules',axis = 1 , inplace = True)

# %%
df.isna().sum()
# Out:
# id                                    0
# NAME                                250
# host_identity_verified              289
# host name                           406
# neighbourhood group                  29
# neighbourhood                        16
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      409
# number of reviews                   183
# last review                       15893
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# dtype: int64

# %%
df.dropna(axis = 0, how='any' , inplace = True)

# %%
df.isna().sum()
# Out:
# id                                0
# NAME                              0
# host_identity_verified            0
# host name                         0
# neighbourhood group               0
# neighbourhood                     0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# Construction year                 0
# price                             0
# service fee                       0
# minimum nights                    0
# number of reviews                 0
# last review                       0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# dtype: int64

# %%
len(df)
# Out:
# 84319

# %%
df['service fee']=df['service fee'].str.replace('$','').str.replace(',','')

# %%
df['price']=df['price'].str.replace('$','').str.replace(',','')

# %%
room_type_count=df['room type'].value_counts()

# %%
room_type_count
# Out:
# room type
# Entire home/apt    44631
# Private room       37899
# Shared room         1677
# Hotel room           112
# Name: count, dtype: int64

# %%
cancellation_counts = df['cancellation_policy'].value_counts()

# %%
cancellation_counts
# Out:
# cancellation_policy
# moderate    28257
# strict      28072
# flexible    27990
# Name: count, dtype: int64

# %%
df.sort_values(by = 'number of reviews',ascending=False).head(10)
# Out:
#              id                                               NAME  \
# 52488  29990458             Sonder Battery Park | Studio Apartment
# 62244  35378697                                          City King
# 49799  28505324  Amazing Micro Unit W/ communal rooftop and kit...
# 53078  30316315                     Enjoy great views of the City!
# 49653  28424688  Come catch a Broadway Show & stay in Times Square
# 49827  28520788         Hudson River View King Bed at Higher Floor
# 49605  28398178          Beautiful Standard Full Room at The Ridge
# 57532  32776260                                     King Room City
# 50780  29047130                 THE PRIVACY DEN ~ 5 MINUTES TO JFK
# 54308  30995644       Entire New Apartment in Park Slope / Gowanus
#
#       host_identity_verified     host name neighbourhood group  \
# 52488               verified  Sonder (NYC)           Manhattan
# 62244               verified     Arlo SoHo           Manhattan
# ...

# %%
boolean_mask = (df['review rate number']>= 3)  & (df['review rate number']<= 4 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84319 entries, 0 to 102597
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              84319 non-null  int64
#  1   NAME                            84319 non-null  object
#  2   host_identity_verified          84319 non-null  object
#  3   host name                       84319 non-null  object
#  4   neighbourhood group             84319 non-null  object
#  5   neighbourhood                   84319 non-null  object
#  6   instant_bookable                84319 non-null  object
#  7   cancellation_policy             84319 non-null  object
#  8   room type                       84319 non-null  object
#  9   Construction year               84319 non-null  float64
#  10  price                           84319 non-null  object
#  11  service fee                     84319 non-null  object
# ...

# %%
df['review rate number']=df['review rate number'].astype(int)

# %%
boolean_mask = (df['review rate number']>= 3)  & (df['review rate number']<= 4 )

# %%
filtered_hotels = df[boolean_mask]
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
room_type_counts = df['room type'].value_counts()

# %%
room_type_counts
# Out:
# room type
# Entire home/apt    44631
# Private room       37899
# Shared room         1677
# Hotel room           112
# Name: count, dtype: int64

# %%
room_type_counts.plot(kind = 'bar')
plt.title("Room type distribution")
plt.xlabel('room type')
plt.ylabel('count')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(10,5))
policy = df.groupby('cancellation_policy')['id'].count().plot(kind = 'pie' , autopct = '%1.1f%%' , colormap = 'Blues').set()

# %%
fig , ax = plt.subplots(figsize= (10,5))
df.groupby('Construction year')['id'].count().plot(kind = 'line')
ax.set(title = 'Construction years of Airbnb ' , xlabel = 'Construction year')
ax.set_xlim(2000 , 2022)
ax.set_ylim(4950 , 5300)
plt.show()

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
features = ['price' , 'reviews per month' , 'review rate number']

# %%
data = df[features].copy()

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
inertia = []
for k in range(1 , 10):
  kmeans = KMeans(n_clusters = k , random_state = 42)
  kmeans.fit(scaled_data)
  inertia.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,10) , inertia , marker = 'o')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score , classification_report

x = df[['reviews per month' , 'review rate number' , 'price']]
y= df['room type']

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

clf = DecisionTreeClassifier(random_state =42)
clf.fit(x_train , y_train)

y_pred = clf.predict(x_test)

accuracy = accuracy_score(y_test , y_pred)

print(accuracy)
print(classification_report(y_test , y_pred))
# Out:
# 0.7351755218216319
#                  precision    recall  f1-score   support
#
# Entire home/apt       0.76      0.75      0.76      8909
#      Hotel room       0.07      0.05      0.06        22
#    Private room       0.72      0.73      0.72      7603
#     Shared room       0.48      0.51      0.49       330
#
#        accuracy                           0.74     16864
#       macro avg       0.51      0.51      0.51     16864
#    weighted avg       0.74      0.74      0.74     16864

# %% [markdown]
# People prefer entire home/apartments and private rooms  as they want privacy so they are ready to pay more .
