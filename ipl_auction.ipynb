# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/IPL_2023-22_Sold_Players.csv")

# %%
df.head(10)
# Out:
#    Season             Name Nationality            Type                  Team  \
# 0    2023  Ajinkya Rahane      Indian          Batter    Chennai Super Kings
# 1    2023   Bhagath Varma      Indian     All-Rounder    Chennai Super Kings
# 2    2023   Kyle Jamieson    Overseas          Bowler    Chennai Super Kings
# 3    2023     Ajay Mandal      Indian     All-Rounder    Chennai Super Kings
# 4    2023  Nishant Sindhu      Indian     All-Rounder    Chennai Super Kings
# 5    2023   Shaik Rasheed      Indian          Batter    Chennai Super Kings
# 6    2023      Ben Stokes    Overseas     All-Rounder    Chennai Super Kings
# 7    2023       Phil Salt    Overseas   Wicket-Keeper         Delhi Capitals
# 8    2023   Ishant Sharma      Indian          Bowler         Delhi Capitals
# 9    2023   Rilee Rossouw    Overseas          Batter         Delhi Capitals
#
#            Price
# 0     50,00,000
# 1     20,00,000
# 2   1,00,00,000
# 3     20,00,000
# 4     60,00,000
# 5     20,00,000
# 6  16,25,00,000
# 7   2,00,00,000
# 8     50,00,000
# 9   4,60,00,000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       284 non-null    int64
#  1   Name         284 non-null    object
#  2   Nationality  284 non-null    object
#  3   Type         284 non-null    object
#  4   Team         284 non-null    object
#  5   Price        284 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 13.4+ KB

# %%
df['Price'] = df['Price'].apply(lambda x : str(x).replace(',','')).astype(float)

# %%
df
# Out:
#      Season               Name Nationality          Type  \
# 0      2023    Ajinkya Rahane      Indian        Batter
# 1      2023     Bhagath Varma      Indian   All-Rounder
# 2      2023     Kyle Jamieson    Overseas        Bowler
# 3      2023       Ajay Mandal      Indian   All-Rounder
# 4      2023    Nishant Sindhu      Indian   All-Rounder
# ..      ...                ...         ...           ...
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team       Price
# 0     Chennai Super Kings   5000000.0
# 1     Chennai Super Kings   2000000.0
# 2     Chennai Super Kings  10000000.0
# 3     Chennai Super Kings   2000000.0
# 4     Chennai Super Kings   6000000.0
# ..                    ...         ...
# 279   Sunrisers Hyderabad   5000000.0
# 280   Sunrisers Hyderabad  24000000.0
# 281   Sunrisers Hyderabad   2000000.0
# 282   Sunrisers Hyderabad   2000000.0
# 283   Sunrisers Hyderabad   2000000.0
#
# [284 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Season', 'Name', 'Nationality', 'Type', 'Team', 'Price'], dtype='object')

# %%
for col in df.columns:
  print("no of unique values in ", col , " are " , df[col].nunique())
# Out:
# no of unique values in  Season  are  2
# no of unique values in  Name  are  266
# no of unique values in  Nationality  are  2
# no of unique values in  Type  are  6
# no of unique values in  Team  are  10
# no of unique values in  Price  are  66

# %%
df['Type'].unique()
# Out:
# array(['Batter ', 'All-Rounder ', 'Bowler ', 'Wicket-Keeper ', 'Batsman ',
#        'Wicket Keeper '], dtype=object)

# %%
df['Type']=df['Type'].apply(lambda x: x.replace('Batter ','Batsman'))

# %%
df['Type'] = df['Type'].apply(lambda x: x.replace('All-Rounder ','All-Rounder'))

# %%
df['Type'] = df['Type'].apply(lambda x: x.replace('Bowler ','Bowler'))

# %%
df['Type'] = df['Type'].apply(lambda x: x.replace('Wicket-Keeper ','Wicket-Keeper'))

# %%
df['Type'] = df['Type'].apply(lambda x: x.replace('Batsman ','Batsman'))

# %%
df['Type'] = df['Type'].apply(lambda x: x.replace('Wicket Keeper ','Wicket-Keeper'))

# %%
df['Type'].unique()
# Out:
# array(['Batsman', 'All-Rounder', 'Bowler', 'Wicket-Keeper'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Nationality'].value_counts()
# Out:
# Nationality
# Indian       188
# Overseas      96
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Season         0
# Name           0
# Nationality    0
# Type           0
# Team           0
# Price          0
# dtype: int64

# %%
df.groupby('Nationality')['Price'].mean()
# Out:
# Nationality
# Indian       1.894415e+07
# Overseas     3.776562e+07
# Name: Price, dtype: float64

# %%
df['Nationality']=df['Nationality'].apply(lambda x: 'na' if 'not available' in x else x )

# %%
df.head(20)
# Out:
#     Season                 Name Nationality           Type  \
# 0     2023      Ajinkya Rahane      Indian         Batsman
# 1     2023       Bhagath Varma      Indian     All-Rounder
# 2     2023       Kyle Jamieson    Overseas          Bowler
# 3     2023         Ajay Mandal      Indian     All-Rounder
# 4     2023      Nishant Sindhu      Indian     All-Rounder
# 5     2023       Shaik Rasheed      Indian         Batsman
# 6     2023          Ben Stokes    Overseas     All-Rounder
# 7     2023           Phil Salt    Overseas   Wicket-Keeper
# 8     2023       Ishant Sharma      Indian          Bowler
# 9     2023       Rilee Rossouw    Overseas         Batsman
# 10    2023       Manish Pandey      Indian         Batsman
# 11    2023        Mukesh Kumar      Indian          Bowler
# 12    2023         Shivam Mavi      Indian          Bowler
# 13    2023         K.S. Bharat      Indian   Wicket-Keeper
# 14    2023         Urvil Patel      Indian   Wicket-Keeper
# 15    2023        Mohit Sharma      Indian          Bowler
# 16    2023       Joshua Little    Overseas          Bowler
# 17    2023     Kane Williamson    Overseas         Batsman
# 18    2023         Odean Smith    Overseas     All-Rounder
# 19    2023  Kulwant Khejroliya      Indian          Bowler
#
#                       Team        Price
# 0      Chennai Super Kings    5000000.0
# 1      Chennai Super Kings    2000000.0
# 2      Chennai Super Kings   10000000.0
# 3      Chennai Super Kings    2000000.0
# 4      Chennai Super Kings    6000000.0
# 5      Chennai Super Kings    2000000.0
# 6      Chennai Super Kings  162500000.0
# 7           Delhi Capitals   20000000.0
# 8           Delhi Capitals    5000000.0
# 9           Delhi Capitals   46000000.0
# 10          Delhi Capitals   24000000.0
# 11          Delhi Capitals   55000000.0
# 12          Gujarat Titans   60000000.0
# 13          Gujarat Titans   12000000.0
# 14          Gujarat Titans    2000000.0
# 15          Gujarat Titans    5000000.0
# 16          Gujarat Titans   44000000.0
# 17          Gujarat Titans   20000000.0
# 18          Gujarat Titans    5000000.0
# 19   Kolkata Knight Riders    2000000.0

# %%
df['Team'].unique()
# Out:
# array([' Chennai Super Kings', ' Delhi Capitals', ' Gujarat Titans',
#        ' Kolkata Knight Riders', ' Lucknow Super Giants',
#        ' Mumbai Indians', ' Punjab Kings', ' Rajasthan Royals',
#        ' Royal Challengers Bangalore', ' Sunrisers Hyderabad'],
#       dtype=object)

# %%
top_10_paid = df.groupby('Name')['Price'].mean().sort_values(ascending = False).head(10)

# %%
top_10_paid
# Out:
# Name
# Sam Curran           185000000.0
# Cameron Green        175000000.0
# Ben Stokes           162500000.0
# Ishan Kishan         152500000.0
# Deepak Chahar        140000000.0
# Nicholas Pooran      133750000.0
# Harry Brook          132500000.0
# Shreyas Iyer         122500000.0
# Liam Livingstone     115000000.0
# Harshal Patel        107500000.0
# Name: Price, dtype: float64

# %%
fig = px.bar(x = top_10_paid.index , y=top_10_paid.values , color = top_10_paid.index , text = top_10_paid.values)
fig.update_layout(xaxis_title = 'Players' , yaxis_title = 'Price' )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ab3a3256-6cee-454d-8377-f4a4c71574de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab3a3256-6cee-454d-8377-f4a4c71574de")) {                    Plotly.newPlot(                        "ab3a3256-6cee-454d-8377-f4a4c71574de",                        [{"alignmentgroup":"True","hovertemplate":"color=Sam Curran \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sam Curran ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sam Curran ","offsetgroup":"Sam Curran ","orientation":"v","showlegend":true,"text":[185000000.0],"textposition":"auto","x":["Sam Curran "],"xaxis":"x","y":[185000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Cameron Green \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cameron Green ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cameron Green ","offsetgroup":"Cameron Green ","orientation":"v","showlegend":true,"text":[175000000.0],"textposition":"auto","x":["Cameron Green "],"xaxis":"x","y":[175000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ben Stokes \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ben Stokes ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ben Stokes ","offsetgroup":"Ben Stokes ","orientation":"v","showlegend":true,"text":[162500000.0],"textposition":"auto","x":["Ben Stokes "],"xaxis":"x","y":[162500000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ishan Kishan \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ishan Kishan ","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Ishan Kishan ","offsetgroup":"Ishan Kishan ","orientation":"v","showlegend":true,"text":[152500000.0],"textposition":"auto","x":["Ishan Kishan "],"xaxis":"x","y":[152500000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Deepak Chahar \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deepak Chahar ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Deepak Chahar ","offsetgroup":"Deepak Chahar ","orientation":"v","showlegend":true,"text":[140000000.0],"textposition":"auto","x":["Deepak Chahar "],"xaxis":"x","y":[140000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nicholas Pooran \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nicholas Pooran ","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Nicholas Pooran ","offsetgroup":"Nicholas Pooran ","orientation":"v","showlegend":true,"text":[133750000.0],"textposition":"auto","x":["Nicholas Pooran "],"xaxis":"x","y":[133750000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Harry Brook \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Harry Brook ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Harry Brook ","offsetgroup":"Harry Brook ","orientation":"v","showlegend":true,"text":[132500000.0],"textposition":"auto","x":["Harry Brook "],"xaxis":"x","y":[132500000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shreyas Iyer \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shreyas Iyer ","marker":{ ...

# %%
lowest_paid = df.groupby('Name')['Price'].mean().sort_values(ascending=True).head(10)

# %%
lowest_paid
# Out:
# Name
# Abdul P A             2000000.0
# Mukesh Choudhary      2000000.0
# Mohsin Khan           2000000.0
# Mohit Rathee          2000000.0
# Mohd. Arshad Khan     2000000.0
# Tejas Baroka          2000000.0
# Mayank Yadav          2000000.0
# Yudhvir Charak        2000000.0
# Manoj Bhandage        2000000.0
# Manan Vohra           2000000.0
# Name: Price, dtype: float64

# %%
import plotly.express as px

# %%
fig = px.bar(x = lowest_paid.index, y = lowest_paid.values , color = lowest_paid.index , text = lowest_paid.values,
             title = 'lowest_paid_players')
fig.update_layout(xaxis_title = 'Players' ,  yaxis_title = 'Amount')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35c24a2f-9796-491e-99d4-d6ba6a4709dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35c24a2f-9796-491e-99d4-d6ba6a4709dc")) {                    Plotly.newPlot(                        "35c24a2f-9796-491e-99d4-d6ba6a4709dc",                        [{"alignmentgroup":"True","hovertemplate":"color=Abdul P A \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Abdul P A ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Abdul P A ","offsetgroup":"Abdul P A ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Abdul P A "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mukesh Choudhary \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mukesh Choudhary ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Mukesh Choudhary ","offsetgroup":"Mukesh Choudhary ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Mukesh Choudhary "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mohsin Khan \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mohsin Khan ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mohsin Khan ","offsetgroup":"Mohsin Khan ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Mohsin Khan "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mohit Rathee \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mohit Rathee ","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Mohit Rathee ","offsetgroup":"Mohit Rathee ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Mohit Rathee "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mohd. Arshad Khan \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mohd. Arshad Khan ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mohd. Arshad Khan ","offsetgroup":"Mohd. Arshad Khan ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Mohd. Arshad Khan "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Tejas Baroka \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tejas Baroka ","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Tejas Baroka ","offsetgroup":"Tejas Baroka ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Tejas Baroka "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mayank Yadav \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mayank Yadav ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Mayank Yadav ","offsetgroup":"Mayank Yadav ","orientation":"v","showlegend":true,"text":[2000000.0],"textposition":"auto","x":["Mayank Yadav "],"xaxis":"x","y":[2000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Yudhvir Charak \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yudhvir Charak ","marker": ...

# %%
df.head()
# Out:
#    Season             Name Nationality         Type                  Team  \
# 0    2023  Ajinkya Rahane      Indian       Batsman   Chennai Super Kings
# 1    2023   Bhagath Varma      Indian   All-Rounder   Chennai Super Kings
# 2    2023   Kyle Jamieson    Overseas        Bowler   Chennai Super Kings
# 3    2023     Ajay Mandal      Indian   All-Rounder   Chennai Super Kings
# 4    2023  Nishant Sindhu      Indian   All-Rounder   Chennai Super Kings
#
#         Price
# 0   5000000.0
# 1   2000000.0
# 2  10000000.0
# 3   2000000.0
# 4   6000000.0

# %%
features = ['Name' , 'Nationality' , 'Type' , 'Team']
for f in features:
  cont = df.groupby(f)['Price'].mean().sort_values(ascending=False).head(5)
  fig = px.bar(x = cont.index , y = cont.values , color = cont.index , text = cont.values)
  fig.update_layout()
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a8ee0e2e-7503-441b-8acb-70bf21e4ceae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8ee0e2e-7503-441b-8acb-70bf21e4ceae")) {                    Plotly.newPlot(                        "a8ee0e2e-7503-441b-8acb-70bf21e4ceae",                        [{"alignmentgroup":"True","hovertemplate":"color=Sam Curran \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sam Curran ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sam Curran ","offsetgroup":"Sam Curran ","orientation":"v","showlegend":true,"text":[185000000.0],"textposition":"auto","x":["Sam Curran "],"xaxis":"x","y":[185000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Cameron Green \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cameron Green ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cameron Green ","offsetgroup":"Cameron Green ","orientation":"v","showlegend":true,"text":[175000000.0],"textposition":"auto","x":["Cameron Green "],"xaxis":"x","y":[175000000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ben Stokes \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ben Stokes ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ben Stokes ","offsetgroup":"Ben Stokes ","orientation":"v","showlegend":true,"text":[162500000.0],"textposition":"auto","x":["Ben Stokes "],"xaxis":"x","y":[162500000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ishan Kishan \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ishan Kishan ","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Ishan Kishan ","offsetgroup":"Ishan Kishan ","orientation":"v","showlegend":true,"text":[152500000.0],"textposition":"auto","x":["Ishan Kishan "],"xaxis":"x","y":[152500000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Deepak Chahar \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deepak Chahar ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Deepak Chahar ","offsetgroup":"Deepak Chahar ","orientation":"v","showlegend":true,"text":[140000000.0],"textposition":"auto","x":["Deepak Chahar "],"xaxis":"x","y":[140000000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cc6c7ae2-8277-4e6d-8e89-a4f9f42b4cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc6c7ae2-8277-4e6d-8e89-a4f9f42b4cc7")) {                    Plotly.newPlot(                        "cc6c7ae2-8277-4e6d-8e89-a4f9f42b4cc7",                        [{"alignmentgroup":"True","hovertemplate":"color=Overseas \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Overseas ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Overseas ","offsetgroup":"Overseas ","orientation":"v","showlegend":true,"text":[37765625.0],"textposition":"auto","x":["Overseas "],"xaxis":"x","y":[37765625.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Indian \u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Indian ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Indian ","offsetgroup":"Indian ","orientation":"v","showlegend":true,"text":[18944148.936170213],"textposition":"auto","x":["Indian "],"xaxis":"x","y":[18944148.936170213],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="220c49e8-a843-48a7-a92c-ba4d43e8a8cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("220c49e8-a843-48a7-a92c-ba4d43e8a8cb")) {                    Plotly.newPlot(                        "220c49e8-a843-48a7-a92c-ba4d43e8a8cb",                        [{"alignmentgroup":"True","hovertemplate":"color=Wicket-Keeper\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wicket-Keeper","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Wicket-Keeper","offsetgroup":"Wicket-Keeper","orientation":"v","showlegend":true,"text":[28161764.70588235],"textposition":"auto","x":["Wicket-Keeper"],"xaxis":"x","y":[28161764.70588235],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Batsman\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Batsman","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Batsman","offsetgroup":"Batsman","orientation":"v","showlegend":true,"text":[27260416.666666668],"textposition":"auto","x":["Batsman"],"xaxis":"x","y":[27260416.666666668],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=All-Rounder\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"All-Rounder","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"All-Rounder","offsetgroup":"All-Rounder","orientation":"v","showlegend":true,"text":[26801886.79245283],"textposition":"auto","x":["All-Rounder"],"xaxis":"x","y":[26801886.79245283],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bowler\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bowler","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bowler","offsetgroup":"Bowler","orientation":"v","showlegend":true,"text":[21666666.666666668],"textposition":"auto","x":["Bowler"],"xaxis":"x","y":[21666666.666666668],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="18b48ab7-22de-4996-9a06-5aa8eb5a79b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18b48ab7-22de-4996-9a06-5aa8eb5a79b2")) {                    Plotly.newPlot(                        "18b48ab7-22de-4996-9a06-5aa8eb5a79b2",                        [{"alignmentgroup":"True","hovertemplate":"color= Sunrisers Hyderabad\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Sunrisers Hyderabad","marker":{"color":"#636efa","pattern":{"shape":""}},"name":" Sunrisers Hyderabad","offsetgroup":" Sunrisers Hyderabad","orientation":"v","showlegend":true,"text":[31393939.393939395],"textposition":"auto","x":[" Sunrisers Hyderabad"],"xaxis":"x","y":[31393939.393939395],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color= Punjab Kings\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Punjab Kings","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":" Punjab Kings","offsetgroup":" Punjab Kings","orientation":"v","showlegend":true,"text":[30534482.75862069],"textposition":"auto","x":[" Punjab Kings"],"xaxis":"x","y":[30534482.75862069],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color= Lucknow Super Giants\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Lucknow Super Giants","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":" Lucknow Super Giants","offsetgroup":" Lucknow Super Giants","orientation":"v","showlegend":true,"text":[28142857.14285714],"textposition":"auto","x":[" Lucknow Super Giants"],"xaxis":"x","y":[28142857.14285714],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color= Delhi Capitals\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Delhi Capitals","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":" Delhi Capitals","offsetgroup":" Delhi Capitals","orientation":"v","showlegend":true,"text":[24960000.0],"textposition":"auto","x":[" Delhi Capitals"],"xaxis":"x","y":[24960000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color= Gujarat Titans\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":" Gujarat Titans","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":" Gujarat Titans","offsetgroup":" Gujarat Titans","orientation":"v","showlegend":true,"text":[24685185.185185187],"textposition":"auto","x":[" Gujarat Titans"],"xaxis":"x","y":[24685185.185185187],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...

# %% [markdown]
# We can analyse from this that
#
# 1) OVerseas batsman are getting more income than national players
#
# 2) Wicket keepers are taking the highest price and bowlers the least
#
# 3) sunrisers hyderabad is the costliest team
